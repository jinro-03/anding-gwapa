# %% [markdown]
# <a href="https://colab.research.google.com/github/jinro-03/anding-gwapa/blob/main/Another_copy_of_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 1 — Seeing the Climate Through Data
#
# **Welcome!** Today we explore real datasets to see how Earth's climate is changing — and why.
#
# ---
#
# ## Contents
#
# - **PART I** — From raw numbers to global and local patterns
# - **PART II** — Temperature on Earth is changing. What is driving these changes?
# - **PART III** — Climate in Negros and the Philippines
#
# ## Setup
#
# Run this cell first. It installs the workshop tools and connects to your Google Drive.

# %%
# 1
import os                                                                          # in English:
if not os.path.exists("/content/USLS-Workshop"):                                   # IF workshop isn't downloaded yet:
    # !git clone "https://github.com/Cas-Dec/USLS-Workshop.git" /content/USLS-Workshop  # download the workshop
# open the workshop
# %cd /content/USLS-Workshop
# !pip install -q .                                                                  # install what is needed to do the workshop

# %cd /content/USLS-Workshop/notebooks

#from google.colab import drive
#drive.mount('/content/drive')                                                      # connect to your Google Drive
# Out:
# Cloning into '/content/USLS-Workshop'...
# remote: Enumerating objects: 391, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 391 (delta 47), reused 69 (delta 30), pack-reused 298 (from 2)
# Receiving objects: 100% (391/391), 92.49 MiB | 26.85 MiB/s, done.
# Resolving deltas: 100% (176/176), done.
# Updating files: 100% (76/76), done.
# /content/USLS-Workshop
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for workshop-utils (pyproject.toml) ... done
# /content/USLS-Workshop/notebooks

# %%
# 2
import numpy as np                                                      # anything with numbers
import pandas as pd                                                     # anything with tables
import xarray as xr                                                     # geospatial data
import matplotlib.pyplot as plt                                         # make visuals
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches

print("Ready!")
# Out:
# Ready!

# %% [markdown]
# ---
#
# # PART I — From raw numbers to global and local patterns
#
# ## 1) What is 'climate data'?
#
# Before we analyse anything, we need to understand what we are working with. In this workshop we use real observational datasets collected, cleaned, and published by scientific research groups. Today we start with **two widely used global temperature records**:
#
# 1. **Berkeley Earth Surface Temperature (BEST)**
#    A globally gridded land–ocean temperature record compiled from thousands of weather stations and ocean buoys.
#    👉 https://berkeleyearth.org/data/
#
# 2. **NASA GISTEMP**
#    A global temperature-anomaly record maintained by NASA's Goddard Institute for Space Studies.
#    👉 https://data.giss.nasa.gov/gistemp/
#
# Both records express temperature as an **[anomaly](https://en.wikipedia.org/wiki/Temperature_anomaly)**: the difference **from** the average temperature over a **reference period** (1951–1980 for both datasets). A positive anomaly means warmer than that baseline; negative means cooler. Using anomalies rather than absolute temperatures makes it easier to compare stations at different altitudes and latitudes.
#
# We have already downloaded and lightly processed these datasets. Let's load and inspect them.
#
# 💡 `EXAMPLE — Reading .csv data`
#
# `.csv`, or "comma-separated value" data, is a very typical format used for tabular data (anything with rows and columns) in e.g. Microsoft Excel. Above, we imported the `pandas` library, which is perfect for this type of data, and abbreviated it as `pd` so we can write it in short. You can use pandas to open a .csv file by using:
#
# `pd.read_csv('your-csv-file-name-here.csv')`
#
# The BEST data is under the folder `../data/processed/day1/`, and the file name is `"best_yearly.csv"`. Here's how you use pandas to read it:

# %%
# 3
# 💡 Reading .csv data with pandas
# --- Load Berkeley Earth ---
best = pd.read_csv("../data/processed/day1/best_yearly.csv")   # using pandas to read our Berkeley Earth data

# 💡 Using head() to inspect pandas data
best.head(10)                                           # show the first 10 rows
# Out:
#    Year   Anomaly
# 0  1850 -0.435667
# 1  1851 -0.320750
# 2  1852 -0.292250
# 3  1853 -0.294500
# 4  1854 -0.283333
# 5  1855 -0.278250
# 6  1856 -0.396333
# 7  1857 -0.537833
# 8  1858 -0.334167
# 9  1859 -0.222250

# %% [markdown]
# > 💬 **Discussion:** What do you think these numbers represent? What does `Year = 1850`, `Anomaly = -0.44` mean physically?
#
# **🖊️ Your turn**: load the NASA GISTEMP data yourself
#
# The file is called `"gistemp_yearly.csv"` and is also under `../data/processed/day1/`, can you fill in the missing part below? *Hint: look at how it was done in the code cell above...*

# %%
# 4
# --- Load NASA GISTEMP ---
gistemp = pd.read_csv("../data/processed/day1/gistemp_yearly.csv")          # ✏️ fill in the missing part
gistemp.head(10)                                # ✏️ show the first 10 rows of the GISTEMP data
# Out:
#    Year   Anomaly
# 0  1880 -0.176667
# 1  1881 -0.090833
# 2  1882 -0.110833
# 3  1883 -0.173333
# 4  1884 -0.284167
# 5  1885 -0.335833
# 6  1886 -0.318333
# 7  1887 -0.365833
# 8  1888 -0.180000
# 9  1889 -0.109167

# %% [markdown]
# ---
#
# ## 2) The global temperature trend — *the hockey-stick curve*
#
# Now let's actually *see* the data. When you visualize the temperature data, you'll notice something about its shape in time. It kind of looks like a *hockey stick*, which has now become an unofficial way of referring to it 👉 https://en.wikipedia.org/wiki/Hockey_stick_graph_(global_temperature)
#
# For visualizing the data, we'll use `matplotlib` — the most common Python library for making plots — which we abbreviated as `plt`. Here's how you can use it:

# %%
# 5
# =============================================================
# 💡 EXAMPLE — A matplotlib figure. Uncomment the code lines below one by one, execute the cell every time.
# =============================================================

# 1
#fig, ax = plt.subplots(figsize=(10, 5))                     # create a figure that is 10 inches wide and 5 inches tall

# 2
#x = np.linspace(0, 10, 100)                                 # x is an array of 100 points between 0 and 10

# 3
#y = 2 * x + 1                                               # y is two times x plus 1

# 4
#ax.plot(x, y, label="y = 2x + 1", color="blue")             # on the figure, plot y against x in blue, and label it "y = 2x + 1"

# 5
#ax.legend()                                                 # show the label

# 6
#ax.set_title("Hey look a title!")

# 7
#ax.set_xlabel("The more I do this workshop")

# 8
#ax.set_ylabel("The more I wonder how I ended up here")

# %% [markdown]
# ### 🖊️ Your turn: create the hockey stick curve!
#
# Fill in the `...` where needed below!

# %%
# 6
fig, ax = plt.subplots(figsize=[10, 5])                                     # ✏️ create a 10 inches wide and 5 inches tall

x = best["Year"]
y = best["Anomaly"]

ax.plot(x, y,
        color="blue", linewidth=0.8,                             # ✏️ fill in the missing parts: color="tomato", linewidth=2
        label="y = 2x + 1")                                            # and label it "BEST Temperature Record"

ax.axhline(0, color="gray", linewidth=0.8, linestyle="--")      # horizontal reference line at temperature anomaly 0°

ax.set_title("Global Mean Surface Temperature Anomaly")         # title of the plot
ax.set_xlabel("Year")                                            # ✏️ call the x-axis "Year"
ax.set_ylabel("The more I wonder how I ended up here")                                            # ✏️ call the y-axis "Temperature anomaly (°C)"
ax.legend()                                                             # ✏️ show the legend

# %% [markdown]
# > 💬 **Discussion:** What patterns do you notice? When does the warming really start accelerating?
#
# ---
#
# ## 3) Comparing two datasets
#
# BEST and GISTEMP are produced by different scientific teams using different methods. Do they agree? To check this, you can simply plot them together on the same figure.
#
# ### 🖊️ Your turn: overlay GISTEMP on the BEST record
#
# Copy the structure from the example above. You have:
# - `best["Year"]` and `best["Anomaly"]` for the BEST data
# - `gistemp["Year"]` and `gistemp["Anomaly"]` for GISTEMP
#
# **Tasks:**
# 1. Plot BEST in red (`color="tomato"`) and GISTEMP in blue (`color="steelblue"`)
# 2. Add a title, x-label, y-label, and legend
# 3. Add the `axhline` at zero (copy it from the example above!)

# %%
# 7
fig, ax = plt.subplots(figsize=(10, 4))

# Plot BEST:
ax.plot(best["Year"], best["Anomaly"], color="tomato", linewidth=1.2, label="Berkeley Earth (BEST)")

# ✏️ plot GISTEMP on the same `ax
ax.plot(gistemp["Year"], gistemp["Anomaly"], color="steelblue", linewidth=1.2, label="NASA GISTEMP")

# ✏️ Add an axhline at y=0:
ax.axhline(0, color="gray", linewidth=0.8, linestyle="--")

ax.set_title("Global Mean Surface Temperature Anomaly")
ax.set_xlabel("Year")
ax.set_ylabel("Temperature anomaly (°C)")
ax.legend()

# %% [markdown]
# > 💬 **Discussion:** Do the two datasets agree with each other? Would you trust them more or less because of this?
#
# ---
#
# ## 4) Smoothing noisy data
#
# Year-to-year temperature varies a lot due to natural events like El Niño. A **moving average** smooths out short-term noise to reveal the underlying trend.
#
# Remember that we loaded the BEST data with `pandas`? Pandas has an in-built function for this: `rolling()`. The example below shows a moving average where each point becomes the average of the 10 points surrounding it:

# %%
# 8
# 💡 EXAMPLE — smoothing with pd.rolling()
#------------

# let's create some x, y again:
x = np.linspace(0, 10, 100)
y = np.sin(x) + np.random.normal(0, 0.5, 100)       # y is the sinus of x plus some random noise

fig, ax = plt.subplots()
plt.plot(x, y)

# %% [markdown]
# Let's see if we can make this a bit smoother:

# %%
# 9
# first, we make a pandas version of y:
y_pandas = pd.Series(y)

# then we can use the rolling() method to smooth the data:
y_smoothed = y_pandas.rolling(window=10, center=True).mean()  # smooth the data with a rolling mean

# let's plot the smoothed data on top of the original data:
plt.plot(x, y_smoothed)

# %% [markdown]
# ### 🖊️ Your turn: smooth the BEST record
# Fill in the `...` where needed below!

# %%
# 10
# 10-year moving average (rolling mean)

x = best["Year"]
y = best["Anomaly"]

# ✏️ let each point become the average of the 10 points around it
best_smooth = y.rolling(window=10, center=True).mean()           # Hint: you can just do y.rolling(...)

fig, ax = plt.subplots()

ax.plot(x, y,
        color="tomato", alpha=0.3, linewidth=1, label="BEST (raw)")
ax.plot(x, best_smooth,
        color="darkred", linewidth=2.5, label="BEST (10-yr average)")

ax.axhline(0, color="gray", linewidth=0.8, linestyle="--")
ax.set_title("Global Temperature — Raw vs Smoothed")
ax.set_xlabel("Year")
ax.set_ylabel("Temperature anomaly (°C)")
ax.legend()

# %% [markdown]
# ### 🖊️ Your turn: experiment
# Play around with different values for `window_size` below. What do you notice?

# %%
# 11
# Play around with the window size a couple of times, what do you see?

window_size = 50           # ✏️ whatever window size you want, e.g. 10, 20, 30, 50, 100, etc.

best_very_smooth = best["Anomaly"].rolling(window=window_size, center=True).mean()

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(best["Year"], best_very_smooth,
        color="darkred", linewidth=2.5, label=f"BEST ({window_size}-yr average)")

ax.axhline(0, color="gray", linewidth=0.8, linestyle="--")
ax.set_title("Global Temperature — Raw vs Smoothed")
ax.set_xlabel("Year")
ax.set_ylabel("Temperature anomaly (°C)")
ax.legend()

# %% [markdown]
# > 💬 **Discussion:** Why does smoothing help us understand the trend? What information do we lose when we smooth?
#
# ---
#
# # PART II — Temperature is rising. What is driving these changes?
#
# We see a clear warming trend. But *why* is it happening? Let's examine the most common proposed explanations one by one.
#
# ---
#
# ## 1) Has the sun become dramatically brighter?
#
# The sun's energy output is called **Total Solar Irradiance (TSI)**. It follows an **11-year cycle** driven by **sunspot activity**.
#
# **Sunspots** are temporary dark patches on the sun's surface caused by strong local magnetic fields that suppress convection and make that region slightly cooler than its surroundings. Despite being "dark", a sun with more sunspots is actually *slightly brighter overall*, because the sunspots are accompanied by even brighter surrounding regions called faculae. The number of sunspots rises and falls on a roughly 11-year cycle, producing a corresponding small oscillation in TSI.
# 👉 https://en.wikipedia.org/wiki/Sunspot
#
# In the distant past, **grand solar minima** — prolonged periods of unusually low sunspot activity — contributed to cooling events like the [*Little Ice Age*](https://en.wikipedia.org/wiki/Little_Ice_Age) (roughly 1300–1850 CE).
# 👉 https://en.wikipedia.org/wiki/Solar_minimum
#
# Let's look at the data from NOAA's satellite record.
#
# **🖊️ Your turn**: the monthly data is in a file called `tsi_monthly.csv`, the yearly data in `tsi_yearly.csv`, both under `../data/processed/day1`. You're a pro by now, open them below by filling in the missing `...`:

# %%
# 12
# --- Load Total Solar Irradiance (NOAA) ---
tsi_monthly = pd.read_csv("../data/processed/day1/tsi_monthly.csv")        # ✏️ fill in the missing part
tsi_yearly  = pd.read_csv("../data/processed/day1/tsi_yearly.csv")                     # ✏️ fill in the missing part

# %% [markdown]
# The `print` function is very convenient e.g. for quick checks. You can check out what the `tsi_yearly` data looks like you just opened:

# %%
# 13
# 💡 EXAMPLE — using print
#------------
print(tsi_yearly)
# Out:
#      Year        TSI
# 0    1875  1361.3519
# 1    1876  1361.2981
# 2    1877  1361.3112
# 3    1878  1361.1798
# 4    1879  1361.2242
# ..    ...        ...
# 146  2021  1361.4884
# 147  2022  1361.9811
# 148  2023  1362.4486
# 149  2024  1362.5645
# 150  2025  1362.4166
#
# [151 rows x 2 columns]

# %% [markdown]
# Or just what columns it has:

# %%
# 14
print(tsi_yearly.columns)
# Out:
# Index(['Year', 'TSI'], dtype='object')

# %% [markdown]
# You can get only the `pd` table column you're interested in by using square brackets `[...]`:

# %%
# 15
print(tsi_yearly["Year"])
# Out:
# 0      1875
# 1      1876
# 2      1877
# 3      1878
# 4      1879
#        ...
# 146    2021
# 147    2022
# 148    2023
# 149    2024
# 150    2025
# Name: Year, Length: 151, dtype: int64

# %% [markdown]
# *But what if you just quickly want to check what the first and last year in the data are?* Let's do this. In general, words / sentences in Python are a type of data called `strings`. E.g. if I say:

# %%
# 16
my_name = "Cas"

# %% [markdown]
# Then `my_name` is a string type:

# %%
# 17
type(my_name)
# Out:
# str

# %% [markdown]
# You can do fun stuff with strings. Here:

# %%
# 18
# 💡 EXAMPLE — parsing into a string
#------------

my_cat = "Mellie"
my_dog = "Sydje"
observation = f"Hey look! {my_dog} is running after {my_cat}!"
print(observation)
# Out:
# Hey look! Sydje is running after Mellie!

# %% [markdown]
# See that? putting `f` in front of a string `"..."` allows you to parse in other stuff using curly brackets `{...}`.
#
# 🖊️ **Try it yourself**:

# %%
# 19
# ✏️ fill in whatever you want to!
my_name = "Andingness"
the_person_next_to_me = "Ambot"
print(f"Hello, my name is {my_name} and the person next to me is {the_person_next_to_me}.")
# Out:
# Hello, my name is Andingness and the person next to me is Ambot.

# %% [markdown]
# **Back to the data.** Let's print the year range of the `tsi` data!

# %%
# 20
tsi_start = tsi_yearly['Year'].min()
tsi_end = tsi_yearly['Year'].max()

print(f"TSI record: {2000} – {2025}")         # ✏️ fill in the missing parts
# Out:
# TSI record: 2000 – 2025

# %% [markdown]
# Now **let's create a** figure where we show the monthly `tsi` on top and the more smooth, yearly `tsi_yearly` on the bottom together with the `best` temperature data. A matplotlib figure consisting of multiple axes or subfigures is called a **subplot**. As you might have guessed, `plt.subplots` is just the tool for that.
#
# Here's how you make a subplot with **two rows and one column**:

# %%
# 21
# 💡 EXAMPLE — creating a figure with subplots
#------------
fig, axes = plt.subplots(2, 1)      # two rows, one column

# %% [markdown]
# Now you don't have one `ax`, but two `axes`. You can plot something different on both of them. ⚠️ **Python starts counting at 0** ⚠️, so if you want to call the first axis it's `axes[0]`, not `axes[1]`. Pretty annoying, I know, but you get used to it quickly.
#
# Here's an example:

# %%
# 22
# 💡 EXAMPLE — plotting on different subplots
#------------

fig, axes = plt.subplots(2, 1)      # two rows, one column

# some random data to plot:
x = np.linspace(0, 10, 100)
y_1 = np.sin(x)
y_2 = x**2

# plot y_1 on the first subplot:
axes[0].plot(x, y_1, color="blue", label="y = sin(x)")      # ⚠️ plotting is done on a specific subplot!

# plot y_2 on the second subplot:
axes[1].plot(x, y_2, color="orange", label="y = x²")

axes[0].set_title("Sine Function")                          # 💡 every subplot can have it's own title
axes[1].set_title("Quadratic Function")

# 💡 You can give the whole figure an overarching title
plt.suptitle("Two Different Functions")
fig.tight_layout()

# %% [markdown]
# **🖊️ You're up:** create a figure with monthly `tsi` on top and the more smooth, yearly `tsi_yearly` on the bottom together with the `best` temperature data.

# %%
# 23
fig, axes = plt.subplots(2, 1, figsize=(10, 5), sharex=True)                # ✏️ create a 2x1 subplot figure that is 11 inches wide and 6 inches tall

# Top panel: monthly TSI showing the 11-year cycle
# ✏️ which axes to plot on? (axes[0] or axes[1]?)
axes[0].plot(pd.to_datetime(tsi_monthly["time"]), tsi_monthly["TSI"], color="goldenrod", linewidth=0.8)                  # ✏️ which axes to plot on? (axes[0] or axes[1]?)

axes[0].set_title("Total Solar Irradiance — monthly (shows 11-year sunspot cycle)")     # ✏️ Give the plot a title
axes[0].set_ylabel("TSI (W m⁻²)")  # ✏️ Set a y-axis label
axes[0].set_xlabel("Year")  # ✏️ Set an x-axis label

# Bottom panel: yearly TSI alongside the BEST temperature anomaly
ax_temp = axes[1].twinx()   # second y-axis on the right

axes[1].plot(pd.to_datetime(tsi_yearly["Year"], format='%Y'), tsi_yearly["TSI"],                                      # ✏️ which axes to plot on? (axes[0] or axes[1]?)
            color="goldenrod", linewidth=1.5,
            linestyle='--', label="TSI (left axis)")
ax_temp.plot(pd.to_datetime(best["Year"], format='%Y'), best["Anomaly"],
             color="tomato", linewidth=2, alpha=0.7, label="BEST temp (right axis)")

axes[0].set_title("Yearly TSI vs Global Temperature")  # ✏️ Give the plot a title
axes[0].set_xlabel("Year")  # ✏️ Set an x-axis label
axes[1].set_ylabel("TSI (W m⁻²)", color="goldenrod")  # ✏️ Set a y-axis label
ax_temp.set_ylabel("Temperature anomaly (°C)", color="tomato")

lines1, labels1 = axes[0].get_legend_handles_labels()
lines2, labels2 = ax_temp.get_legend_handles_labels()
axes[0].legend(lines1 + lines2, labels1 + labels2, loc="upper left")

# %% [markdown]
# > 💬 **Discussion:** Does the long-term trend in solar output match the warming trend?
#
# ---
#
# ## 2) Have volcanoes changed Earth's temperature?
#
# Large volcanic eruptions can inject millions of tonnes of sulphur dioxide (SO₂) into the stratosphere, where it reacts with water vapour to form reflective **sulphate aerosols**. These particles scatter incoming sunlight and can **temporarily cool** the planet by 0.1–0.5°C, typically for 1–3 years.
# 👉 https://en.wikipedia.org/wiki/Volcanic_winter
#
# The most dramatic 20th-century examples:
# - **1963** — [Mount Agung](https://en.wikipedia.org/wiki/Mount_Agung) (Bali, Indonesia) — caused roughly 0.3°C of global cooling
# - **1982** — [El Chichón](https://en.wikipedia.org/wiki/El_Chich%C3%B3n) (Chiapas, Mexico)
# - **1991** — [Mount Pinatubo](https://en.wikipedia.org/wiki/Mount_Pinatubo) (Luzon, **Philippines**) — the largest eruption of the 20th century; cooled global temperatures by ~0.5°C for two years
#
# We use the **Sato–Lacis Aerosol Optical Depth (AOD)** dataset from NASA GISS — a measure of how opaque the stratosphere is to incoming solar radiation. Higher values mean more aerosols and stronger cooling.
# 👉 https://en.wikipedia.org/wiki/Aerosol_optical_depth
#
# 🖊️ **Your turn**: open `aod_global.csv` from ../data/processed/day1/, use `print` to check what it looks like, then use what you see to fill in the missing `...` parts!

# %%
# 24
# --- Load stratospheric AOD (Sato-Lacis, NASA GISS) ---
aod_df     = pd.read_csv("../data/processed/day1/aod_global.csv")        # ✏️ fill in the missing parts
print(aod_df)              # ✏️ fill in the missing parts
# Out:
#              year       aod
# 0     1850.000000  0.004379
# 1     1850.083333  0.004200
# 2     1850.166667  0.003992
# 3     1850.250000  0.003875
# 4     1850.333333  0.003675
# ...           ...       ...
# 2071  2022.583333  0.000000
# 2072  2022.666667  0.000000
# 2073  2022.750000  0.000000
# 2074  2022.833333  0.000000
# 2075  2022.916667  0.000000
#
# [2076 rows x 2 columns]

# %%
# 25
aod_years  = aod_df["year"]      # ✏️ what is the name of the column that contains the years?
aod_global = aod_df["aod"]      # ✏️ what is the name of the column that contains the AOD values?

aod_start = min(aod_years)                 # ✏️ how do you get the first year of the AOD record? Hint: use the `min()` method on the column that contains the years.
aod_end = max(aod_global)                 # ✏️ the last year? Hint: `max()`

print(f'AOD record: {aod_start} - {aod_end}')       # ✏️ Use curly braces to parse oad_start and aod_end into the string.
# Out:
# AOD record: 1850.0 - 0.1598958333333333

# %%
# 26
fig, ax = plt.subplots(figsize=(11, 3.5))

ax.fill_between(aod_years.values, aod_global.values, color="slategray", alpha=0.7)         # ✏️ fill between aod_years.values and aod_global.values
ax.plot(aod_years.values, aod_global.values, color="slategray", linewidth=0.8)             # ✏️ plot aod_global.values against aod_years.values as a line

# Annotate the three major eruptions
for year, name in [(1963, "Agung"), (1982, "El Chichón"), (1991, "Pinatubo")]:
    ax.axvline(year, color="firebrick", linewidth=1, linestyle="--", alpha=0.7)
    ax.text(year + 0.3, aod_global.values.max() * 0.75, name,
            color="firebrick", fontsize=9, rotation=90, va="bottom")

ax.set_title("Global Stratospheric Aerosol Optical Depth — a proxy for volcanic activity")
ax.set_xlabel("Year")
ax.set_ylabel("AOD (stratospheric)")
ax.set_xlim(1860, 2020)
# Out:
# (1860.0, 2020.0)

# %% [markdown]
# > 💬 **Discussion:** Do you see sudden spikes after major eruptions? Could volcanoes explain the *long-term warming trend*?
#
# ---
#
# ## 3) Is it ENSO's fault?
#
# The **El Niño–Southern Oscillation (ENSO)** is the most powerful year-to-year climate driver on Earth. It arises from coupled interactions between ocean surface temperatures and atmospheric circulation over the tropical Pacific.
# 👉 https://en.wikipedia.org/wiki/El_Ni%C3%B1o%E2%80%93Southern_Oscillation
#
# During **El Niño** phases, a pool of unusually warm water spreads across the central and eastern Pacific, releasing large amounts of heat into the atmosphere and pushing global average temperatures up. During **La Niña**, cooler-than-normal water dominates the same region and global temperatures dip slightly. ENSO also shifts rainfall patterns and typhoon tracks across Southeast Asia.
#
# The strength of ENSO is measured by the **Niño 3.4 index** — the average sea-surface temperature anomaly over a defined box in the central-eastern equatorial Pacific (5°N–5°S, 170°W–120°W). By convention, El Niño conditions are declared when this index exceeds +0.5°C for at least five consecutive months; La Niña when it falls below −0.5°C.

# %%
# 27
# --- Load ENSO (Niño 3.4 index, KNMI Climate Explorer) ---
nino_yearly = pd.read_csv("../data/processed/day1/enso_yearly.csv")    # ✏️ file is called "enso_yearly.csv"

print(nino_yearly.head(10))
print(f"ENSO record: {nino_yearly['Year'].min()} – {nino_yearly['Year'].max()}")
# Out:
#    Year      enso
# 0  1854 -0.429609
# 1  1855  0.604493
# 2  1856 -0.812036
# 3  1857 -0.375950
# 4  1858  0.120005
# 5  1859 -0.082617
# 6  1860 -0.669757
# 7  1861 -0.684813
# 8  1862 -0.890195
# 9  1863 -0.556341
# ENSO record: 1854 – 2026

# %%
# 28
# =============================================================
# 💡 EXAMPLE — Colouring above/below zero using fill_between
# ✏️ Becoming a maplotlib ninja! 🥷
# =============================================================

fig, ax = plt.subplots(figsize=(11, 3))     # ✏️ make an 11 inches wide and 3 inches tall figure

years = nino_yearly["Year"]                     # ✏️ you got this!
enso  = nino_yearly["enso"]                    # ✏️ fill in the missing part

ax.fill_between(years, enso, 0,
                where=(enso > 0), color="tomato",      # ✏️ Shade positive El Niño years "tomato"
                alpha=0.6, label="El Niño",
                interpolate=True)

ax.fill_between(years, enso, 0,
                where=(enso < 0), color="steelblue",
                alpha=0.6, label="La Niña",         # ✏️ Shade positive La Niña years "steelblue"
                interpolate=True)

ax.plot(years.values, enso.values, color="black", linewidth=0.6)     # ✏️ plot enso against years
ax.axhline(0, color="black", linewidth=0.8)                 # ✏️ set the horizontal line at y=0 with a linewidth of 0.8

ax.set_xlabel("Year")                                                # ✏️ add x-axis label "Year"

ax.set_ylabel("Niño 3.4 anomaly (°C)")
ax.set_title("ENSO Index (Niño 3.4) — El Niño and La Niña years")
ax.legend()

# %% [markdown]
# ### ENSO vs global temperature
#
# 🖊️ Make a two-panel figure:
# - **Top panel:** The ENSO index
# - **Bottom panel:** The BEST global temperature anomaly
#
# In `plt.subplots(...)`, use `sharex=True` so the x-axes are linked, and limit both panels to the same time period using `ax.set_xlim(1880, 2024)`. This lets you visually compare whether warm (El Niño) years match warm temperature anomalies.

# %%
# 29
# ✏️ Instantiate a subplot with 2 rows and 1 column, and set sharex=True to make the x-axis shared between the two subplots.
fig, axes = plt.subplots(2, 1, figsize=(11, 6), sharex=True)

# --- Top panel: ENSO index ---
# ✏️ Plot the ENSO index (Niño 3.4) as a line with added shading in different colors for El Niño and La Niña years (see cell above for how):
axes[0].plot(years, enso, color="black", linewidth=0.6)
axes[0].fill_between(years, enso, 0,
                where=(enso > 0), color="tomato",
                alpha=0.6, label="El Niño",
                interpolate=True)
axes[0].fill_between(years, enso, 0,
                where=(enso < 0), color="steelblue",
                alpha=0.6, label="La Niña",
                interpolate=True)

axes[0].axhline(0, color="black", linewidth=0.8)        # ✏️ horizontal line at y=0 with a linewidth of 0.8

axes[1].set_ylabel("Niño 3.4 (°C)")
axes[0].set_title("ENSO Index vs Global Temperature")

# --- Bottom panel: BEST temperature ---
# ✏️ Plot the BEST temperature anomaly:

axes[1].plot(best["Year"], best["Anomaly"], color="tomato", linewidth=2)


# ✏️ Add a horizontal line:
axes[1].axhline(0, color="black", linewidth=0.8)
# ✏️ Label y-axis "Temperature anomaly (°C)" and x-axis "Year":
axes[1].set_ylabel("Temperature anomaly (°C)")
axes[0].set_title("Year")

# ✏️ Set the x-axis limits to 1980-2024
axes[1].set_xlim(1880,2024)
# Out:
# (1880.0, 2024.0)

# %% [markdown]
# > 💬 **Discussion:** Do El Niño years (red) tend to coincide with temperature peaks? Can ENSO alone explain the long-term upward trend?
#
# ---
#
# ## 4) What about the Milankovitch cycles?
#
# <img src="https://geologyscience.com/wp-content/uploads/2023/11/Milankovitch-Cycles.webp" width="50%" alt="Milankovitch cycles" />
#
# Even with the sun's brightness and volcanic aerosols held constant, the *timing and distribution* of sunlight reaching Earth still isn't fixed — because Earth's orbit and spin axis wobble on slow, predictable cycles. Serbian geophysicist **Milutin Milanković** worked out in the 1920s that three of these orbital wobbles pace the rhythm of Earth's ice ages.
# 👉 https://en.wikipedia.org/wiki/Milankovitch_cycles
#
# | Cycle | Period | What actually changes |
# |---|---|---|
# | **Eccentricity** | ~100,000 / ~413,000 years | The shape of Earth's orbit around the Sun — nearly circular ↔ slightly elliptical |
# | **Obliquity** (axial tilt) | ~41,000 years | The tilt of Earth's spin axis, oscillating between 22.1° and 24.5° — more tilt means more extreme seasons |
# | **Precession** | ~23,000 years | The direction Earth's spin axis points — which hemisphere faces the Sun at closest approach |
#
# None of these cycles change how much total energy the Sun puts out. What they change is *when and where on Earth* that energy lands — especially how much summer sunlight reaches the high-latitude Northern Hemisphere, where ice sheets grow or retreat. Stack all three together and you get the roughly 100,000-year rhythm of glacial–interglacial cycles you'll see later in this notebook in the ice-core record.
#
# ![Milankovitch cycles: eccentricity, obliquity and precession, and the resulting variation in high-latitude summer insolation](https://upload.wikimedia.org/wikipedia/commons/7/7e/Milankovitch_Variations.png)
#
# *Robert A. Rohde, [Global Warming Art](https://commons.wikimedia.org/wiki/File:Milankovitch_Variations.png), CC BY-SA 3.0 — the same Robert Rohde behind Berkeley Earth, the source of the `best` data you've been plotting all day.*
#
# So could these cycles explain the warming in `best`? According to NASA, no — for two reasons:
# 👉 https://science.nasa.gov/science-research/earth-science/why-milankovitch-orbital-cycles-cant-explain-earths-current-warming/
#
# 1. **Wrong timescale.** Milankovitch cycles unfold over tens to hundreds of thousands of years. The warming in the `best` record has happened over *decades*.
# 2. **Wrong direction.** Based on where Earth currently sits in these cycles, natural orbital forcing predicts slow *cooling* over the coming millennia — continuing a gradual cooling trend that had already been underway for roughly 6,000 years before something reversed it.
#
# > 💬 **Discussion:** If natural orbital forcing points toward slow cooling but we're observing rapid warming instead, what does that tell you about the *sign* of whatever is actually driving the trend?
#
# ---
#
# ## 5) What about CO₂?
#
# **Carbon dioxide (CO₂)** is a **greenhouse gas**: it absorbs outgoing infrared radiation emitted by Earth's surface and re-emits it in all directions, trapping heat in the lower atmosphere. This is the **greenhouse effect** — a natural process that keeps Earth roughly 33°C warmer than it would otherwise be. Human emissions are amplifying it beyond the natural baseline.
# 👉 https://en.wikipedia.org/wiki/Greenhouse_gas
# 👉 https://en.wikipedia.org/wiki/Greenhouse_effect
#
# Since the **[Industrial Revolution](https://en.wikipedia.org/wiki/Industrial_Revolution)** (~1750), humans have burned coal, oil, and natural gas at an ever-increasing rate, releasing CO₂ that was locked underground for millions of years.
#
# The **Keeling Curve** is the longest continuous instrumental record of atmospheric CO₂, measured at the **[Mauna Loa Observatory](https://en.wikipedia.org/wiki/Mauna_Loa_Observatory)** in Hawaii since 1958 by chemist **[Charles David Keeling](https://en.wikipedia.org/wiki/Charles_David_Keeling)**.
# 👉 https://en.wikipedia.org/wiki/Keeling_Curve

# %%
# 30
# --- Load Mauna Loa CO₂ (NOAA Global Monitoring Laboratory) ---
co2        = pd.read_csv ("../data/processed/day1/co2_monthly.csv")       # ✏️ co2_monthly.csv, again under the processed day 1 data
co2_yearly = pd.read_csv ("../data/processed/day1/co2_yearly.csv")        # ✏️ co2_yearly.csv

# ✏️ show the first lines using the head() method:
co2.head(10)
# Out:
#    year  month  decimal date  average  deseasonalized  ndays  sdev   unc
# 0  1958      3     1958.2027   315.71          314.44     -1 -9.99 -0.99
# 1  1958      4     1958.2877   317.45          315.16     -1 -9.99 -0.99
# 2  1958      5     1958.3699   317.51          314.69     -1 -9.99 -0.99
# 3  1958      6     1958.4548   317.27          315.15     -1 -9.99 -0.99
# 4  1958      7     1958.5370   315.87          315.20     -1 -9.99 -0.99
# 5  1958      8     1958.6219   314.93          316.21     -1 -9.99 -0.99
# 6  1958      9     1958.7068   313.21          316.11     -1 -9.99 -0.99
# 7  1958     10     1958.7890   312.42          315.41     -1 -9.99 -0.99
# 8  1958     11     1958.8740   313.33          315.21     -1 -9.99 -0.99
# 9  1958     12     1958.9562   314.67          315.43     -1 -9.99 -0.99

# %%
# 31
fig, axes = plt.subplots(2, 1, figsize=(11, 7), sharex=True)                                     # ✏️ 2x1 subplot, 11 inches wide and 7 inches tall

# --- Top panel: Keeling Curve ---
axes[0].plot(co2["decimal date"], co2["average"],                              # ✏️ plot "average" against "decimal date"
             color="forestgreen", linewidth=0.8)

# ✏️ Title: "Atmospheric CO₂ — the Keeling Curve (Mauna Loa, Hawaii)"
axes[0].set_title("Atmospheric CO₂ — the Keeling Curve (Mauna Loa, Hawaii)")

# ✏️ labels: "CO₂ (ppm)"
axes[0].set_ylabel("CO₂ (ppm)")

# ✏️ Annotate the 350 ppm threshold (often cited as a planetary boundary)
axes[0].axhline(350, color="firebrick", linewidth=1, linestyle="--")
axes[0].text(1960, 352, "350 ppm (planetary boundary)", color="orange", fontsize=8)     # <- text placement at x-value 1960 and y-value 352, just above the horizontal line

# ✏️ Annotate "400 ppm (first exceeded ~2013)", use color "firebrick"
axes[0].axhline(400, color="firebrick", linewidth=1, linestyle="--")
axes[0].text(1960, 352, "400 ppm (first exceeded ~2013)", color="firebrick", fontsize=8)

# --- Bottom panel: CO₂ and temperature on the same time axis ---
axes[1].plot(co2_yearly["year"], co2_yearly["average"],
             color="forestgreen", linewidth=1.8, label="CO₂ (left)")

ax_temp2 = axes[1].twinx()                                      # ✏️ create a second y-axis on the bottom axes[1]. Hint: use the twinx() method
ax_temp2.plot(best["Year"], best["Anomaly"],
              color="tomato", linewidth=1.2, alpha=0.8, label="BEST temp (right)")

axes[1].set_title("CO₂ concentration vs global temperature")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("CO₂ (ppm)", color="forestgreen")
ax_temp2.set_ylabel("Temperature anomaly (°C)", color="tomato")

lines1, labels1 = axes[1].get_legend_handles_labels()
lines2, labels2 = ax_temp2.get_legend_handles_labels()
axes[1].legend(lines1 + lines2, labels1 + labels2, loc="upper left")

# %% [markdown]
# > 💬 **Discussion:** Notice the small wiggles in the monthly CO₂ record. What causes the regular annual up-down oscillation? *(Hint: think about seasons and photosynthesis.)*
#
# ---
#
# ## Correlation vs causation ⚠️
#
# CO₂ and temperature track each other very closely. Let's make a scatter plot to visualise this correlation.

# %%
# 32
# Merge CO₂ and BEST on year (only keep years present in both datasets)
merged = co2_yearly.merge(best, left_on="year", right_on="Year", how="inner")

fig, ax = plt.subplots(figsize=(6, 5))

scatter = ax.scatter(merged["average"], merged["Anomaly"],
                     c=merged["year"], cmap="viridis",
                     s=40, edgecolors="none", alpha=0.85)
plt.colorbar(scatter, ax=ax, label="Year")

ax.set_title("CO₂ vs Global Temperature Anomaly")
ax.set_xlabel("CO₂ concentration (ppm)")
ax.set_ylabel("Temperature anomaly (°C)")
# Out:
# Text(0, 0.5, 'Temperature anomaly (°C)')

# %% [markdown]
# > 💬 **Discussion:** If CO₂ is low, temperature is low. If CO₂ is high, temperature is high. Can you conclude global temperature is caused by atmospheric CO₂ concentration?
#
# The correlation between CO₂ and temperature is striking. But does correlation mean causation?
#
# Consider this: the number of Nicolas Cage films released per year also correlates with drowning deaths in swimming pools. Also: popularity of the first name Brooklyn correlates with UFO sightings in Kentucky. Check out some more spurious correlations 👉 https://www.tylervigen.com/spurious-correlations
#
# So why *do* scientists confidently say CO₂ causes warming?
#
# 1. **Physical mechanism**: The greenhouse properties of CO₂ were first demonstrated in the 1850s. [**Eunice Newton Foote**](https://en.wikipedia.org/wiki/Eunice_Newton_Foote) showed in 1856 that CO₂-filled cylinders heat more strongly in sunlight than air-filled ones. [**John Tyndall**](https://en.wikipedia.org/wiki/John_Tyndall) then proved in 1859 that CO₂ absorbs infrared radiation in precise laboratory experiments. CO₂ *provably* traps heat — this is not a model prediction but a directly measured physical property.
# 2. **Directionality**: [Isotopic analysis](https://en.wikipedia.org/wiki/Isotope_analysis) of atmospheric CO₂ reveals the fingerprint of fossil carbon: the ratio of ¹³C to ¹²C has been declining steadily, exactly as expected when ancient organic carbon (depleted in ¹³C) is burned and added to the atmosphere.
# 3. **Ruling out alternatives**: We have just seen that solar output and volcanoes cannot explain the long-term warming trend, and ENSO produces only year-to-year variation around the trend.
#
# > 💬 **Discussion:** Which of these three points do you find most convincing? Why?
#
# ---
#
# ## *"But CO₂ fluctuates naturally — it's not actually humans' fault!"*
#
# Fair point. CO₂ has varied naturally throughout Earth's history, driven by ice ages, volcanic outgassing, and changes in ocean chemistry. So **how do we know today's rise is unusual?**
#
# The answer lies in **ice cores** — cylinders of ice drilled from the great ice sheets of Antarctica and Greenland. As snow accumulates and compresses over thousands of years, tiny **air bubbles** become trapped inside, preserving samples of the ancient atmosphere at the time the ice formed. By analysing these bubbles, scientists can reconstruct atmospheric CO₂ concentrations going back **800,000 years** — long before any human industrial activity.
# 👉 https://en.wikipedia.org/wiki/Ice_core
#
# Similarly, we can also reconstruct historic atmospheric temperature from ice cores. This is inferred from the **deuterium isotope ratio** (δD) of the ice water itself: warmer periods leave a distinct isotopic fingerprint compared to cold periods, allowing past temperatures to be reconstructed from chemistry alone. The record below comes from **EPICA Dome C** (*European Project for Ice Coring in Antarctica*) — one of the deepest ice cores ever drilled, reaching 3,270 m into East Antarctica and spanning eight complete glacial–interglacial cycles.
# 👉 https://en.wikipedia.org/wiki/European_Project_for_Ice_Coring_in_Antarctica

# %%
# 33
# --- Load the EPICA Dome C ice-core data ---
epica = "epica.csv"        # ✏️ "epica.csv"

# ✏️ explore the data
epica = pd.read_csv("../data/processed/day1/epica.csv")
epica.head(10)
# Out:
#    age_ka  delta_t_c
# 0   0.038       0.88
# 1   0.047       1.84
# 2   0.055       3.04
# 3   0.064       0.35
# 4   0.073      -0.42
# 5   0.082       0.05
# 6   0.091       0.05
# 7   0.100      -0.52
# 8   0.110       0.79
# 9   0.119      -0.55

# %%
# 34
# --- Build a combined figure with EPICA and Mauna Loa ---
fig, ax = plt.subplots(figsize=(11, 5))

# ✏️ plot line with color="#333333", linewidth=0.8
ax.plot(epica["age_ka"], epica["delta_t_c"],
             color="#333333", linewidth=0.8)

# ✏️ fill above and below zero with different colors, set alpha=0.4 (transparency) for both:
color_positive = "tomato"
color_negative = "steelblue"
ax.fill_between(epica["age_ka"], epica["delta_t_c"], 0, where=(epica["delta_t_c"]>=0), color=color_positive,
                alpha=0.4,
                interpolate=True)
ax.fill_between(epica["age_ka"], epica["delta_t_c"], 0, where=(epica["delta_t_c"]<=0), color=color_negative,
                alpha=0.4,
                interpolate=True)


ax.axhline(0, color="gray", linewidth=0.8, linestyle="--")
ax.set_title("EPICA Dome C temperature proxy over 800,000 years")
ax.set_ylabel("Temperature difference (°C)")
ax.set_xlabel("Age model (ka before present)")

# The data is in "ka (thousand years) before present", so if you plot it normally the oldest data will be on the right and the youngest data on the left.
# To make it more intuitive, we can reverse the x-axis so that the oldest data is on the left and the youngest data is on the right.
# ✏️ reverse the x-axis
max_age = epica["age_ka"].max()      # hint: max()
min_age = epica["age_ka"].min()       # hint: min()
ax.set_xlim(max_age, min_age)
# Out:
# (801.662, 0.038)

# %% [markdown]
# > 💬 **Discussion:** What was temperature on Earth like the past 800 000 years? Is it hot now, or cold? When was the last ice age, you think? Can you imagine our ancestors, having to live in a world 10 degrees colder...
#
# The figure above showed *temperature* over 800,000 years from the EPICA ice core. Now let's add *CO₂* — measured from the same kind of ice cores — to see how the two track each other. The CO₂ record comes from the **[Vostok ice core](https://en.wikipedia.org/wiki/Vostok_Station)** in East Antarctica. The trapped air bubbles are analysed directly for their CO₂ content.
#
# The figure below places 800,000 years of natural variability in context. Pay attention to the *scale* of natural CO₂ variation — and where today's Mauna Loa measurements sit by comparison.
#
# ### 🖊️ Temperature and CO₂ together
#
# Make a 2-panel figure (`sharex=True`) that puts both records on the same timeline:
# - **Top panel:** EPICA temperature proxy — copy the red/blue `fill_between` style from the EPICA example above
# - **Bottom panel:** Vostok CO₂ record
#
# Both datasets use *ka before present* on the x-axis. Don’t forget to reverse the x-axis so that time runs left to right (oldest on the left).

# %%
# 35

# %%
# 36
fig, axes = plt.subplots(2, 1, figsize=(11, 7), sharex=True)

# --- Top panel: EPICA temperature ---
ax_t = axes[0]          # 💡 you can call axes whatever you want

# ✏️ line + warm periods red fill + cold periods blue fill:
ax_t.plot(...)
ax_t.fill_between(...)
ax_t.fill_between(...)

ax_t.axhline(0, color="gray", linewidth=0.8, linestyle="--")
ax_t.set_ylabel("Temperature anomaly (°C)")
ax_t.set_title("800,000 years of climate: temperature and CO₂")

# --- Bottom panel: Vostok CO₂ ---
ax_c = axes[1]
# ✏️ Plot the Vostok CO₂ record as a green line:
# ax_c.plot( ... )
ax_c.axhline(280, color="gray", linewidth=0.8, linestyle=":", label="280 ppm — typical interglacial peak")
ax_c.set_ylabel("CO₂ (ppm)")
ax_c.set_xlabel("Age (ka before present)")
ax_c.legend()

# ✏️ Reverse the x-axis so the oldest age is on the left.
# use the same limits as for the EPICA plot above, but reversed (max on the left, min on the right)
# ax_c.set_xlim(..., ...)

# %% [markdown]
# > 💬 **Discussion:** Do you see a pattern between temperature and CO₂? How have humans influenced atmospheric CO₂ concentrations since the industrial revolution? Were there any such concentrations in the past hundreds of thousands of years?
#
# Throughout all eight glacial cycles in the record, CO₂ oscillated between roughly **180 ppm** (glacial, cold) and **280 ppm** (interglacial, warm) — never exceeding 300 ppm naturally. Currently, we sit at about **425-430 ppm**...
#
# ---
#
# ## *"So what? It's just a couple of degrees, and I don't care about polar bears either way. They're mean and eat cute seals."*
#
# For the Philippines, even small shifts in global average temperature translate into:
#
# - 🌊 **Sea level rise** — [thermal expansion](https://en.wikipedia.org/wiki/Thermal_expansion) of the ocean plus glacier and ice-sheet melt threatens low-lying coastal areas
# - 🌀 **Stronger typhoons** — warmer oceans provide more energy; [Typhoon Haiyan (Yolanda, 2013)](https://en.wikipedia.org/wiki/Typhoon_Haiyan) made landfall with winds over 300 km/h, one of the strongest tropical cyclones ever recorded
# - 🌧️ **More extreme rainfall** — warmer air holds more water vapour, intensifying floods and storms
# - 🌾 **Heat stress on crops** — rice yield drops sharply above 35°C
#
# In **Part III** we will zoom into the Philippines and Negros to make this concrete.
#
# ---
#
# # *PART III — Climate in Negros and the Philippines*
#
# ## 1) What is 'climate'?
#
# According to Wikipedia: *"Climate is the long-term weather pattern in a region, typically averaged over 30 years."*
#
# The standard reference period used today is **1991–2020**. Let's look at the average temperature and precipitation across the Philippines during that period using **ERA5** — a global atmospheric **[reanalysis](https://en.wikipedia.org/wiki/Atmospheric_reanalysis)** dataset produced by the [European Centre for Medium-Range Weather Forecasts (ECMWF)](https://en.wikipedia.org/wiki/European_Centre_for_Medium-Range_Weather_Forecasts).
#
# A reanalysis combines historical observations (weather stations, ships, radiosondes, satellites) with a numerical weather model to produce a consistent, gap-free, gridded record of the past atmosphere — filling in areas where direct measurements are sparse or absent.
#
# For the period 1991-2020, we have prepared ERA5 temperature and precipitation climate data for the Philippines in `t2m_clim_mean.nc` and `tp_clim_annual_mean.nc`. ⚠️ Notice that these are **not** `.csv` but rather `.nc` files! These are `NetCDF` data (Network Common Data Form in full), a very typical format for data that has multiple dimensions (e.g. time, latitude, longitude, ...).
#
# 💡 **Reading NetCDF data**
#
# `xarray`, which we imported as `xr`, is the go-to Python library to read `.nc` files. In our case, the data is geospatial, as it has geographical coordinates. If there are multiple variables in the data, we use the `open_dataset` method. For now, temperature and precipitation are in separate files -> The data are individual data arrays, and we use the `open_dataarray` instead:

# %%
# 37
# --- Load ERA5 Philippines climatology (1991–2020) ---
t2m_mean       = xr.open_dataarray("../data/processed/day1/t2m_clim_mean.nc")
tp_mean_annual = xr.open_dataarray("../data/processed/day1/tp_clim_annual_mean.nc")

t2m_mean
# Out:
# <xarray.DataArray 't2m' (latitude: 68, longitude: 52)> Size: 14kB
# [3536 values with dtype=float32]
# Coordinates:
#   * latitude   (latitude) float64 544B 21.25 21.0 20.75 20.5 ... 5.0 4.75 4.5
#   * longitude  (longitude) float64 416B 114.0 114.2 114.5 ... 126.2 126.5 126.8
# Attributes: (12/32)
#     GRIB_paramId:                             167
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      3536
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_totalNumber:                         0
#     GRIB_units:                               K
#     long_name:                                2 metre temperature
#     units:                                    K
#     standard_name:                            unknown
#     GRIB_surface:                             0.0

# %% [markdown]
# Notice how `t2m_mean` is an `xarray.DataArray`, has coordinates and values, and also optional attributes that describe the data. You can still open the same file with `open_dataset`:

# %%
# 38
# 💡 .nc can always be opened with xarray.open_dataset:
lala = xr.open_dataset("../data/processed/day1/t2m_clim_mean.nc")
lala
# Out:
# <xarray.Dataset> Size: 15kB
# Dimensions:    (latitude: 68, longitude: 52)
# Coordinates:
#   * latitude   (latitude) float64 544B 21.25 21.0 20.75 20.5 ... 5.0 4.75 4.5
#   * longitude  (longitude) float64 416B 114.0 114.2 114.5 ... 126.2 126.5 126.8
# Data variables:
#     t2m        (latitude, longitude) float32 14kB ...

# %% [markdown]
# Notice how `lala` is now an xarray.Dataset with one variable called `t2m`. If you want the temperature data, you need to index it:

# %%
# 39
# 💡 getting variables from an xarray.Dataset:
t2m_mean = lala['t2m']  # this is now identical to the t2m_mean we opened above with open_dataarray

# %% [markdown]
# You can also call the **coordinates**:

# %%
# 40
t2m_mean.latitude       # or t2m_mean["latitude"] or t2m_mean.coords["latitude"], all the same
# Out:
# <xarray.DataArray 'latitude' (latitude: 68)> Size: 544B
# array([21.25, 21.  , 20.75, 20.5 , 20.25, 20.  , 19.75, 19.5 , 19.25, 19.  ,
#        18.75, 18.5 , 18.25, 18.  , 17.75, 17.5 , 17.25, 17.  , 16.75, 16.5 ,
#        16.25, 16.  , 15.75, 15.5 , 15.25, 15.  , 14.75, 14.5 , 14.25, 14.  ,
#        13.75, 13.5 , 13.25, 13.  , 12.75, 12.5 , 12.25, 12.  , 11.75, 11.5 ,
#        11.25, 11.  , 10.75, 10.5 , 10.25, 10.  ,  9.75,  9.5 ,  9.25,  9.  ,
#         8.75,  8.5 ,  8.25,  8.  ,  7.75,  7.5 ,  7.25,  7.  ,  6.75,  6.5 ,
#         6.25,  6.  ,  5.75,  5.5 ,  5.25,  5.  ,  4.75,  4.5 ])
# Coordinates:
#   * latitude  (latitude) float64 544B 21.25 21.0 20.75 20.5 ... 5.0 4.75 4.5
# Attributes:
#     units:             degrees_north
#     standard_name:     latitude
#     long_name:         latitude
#     stored_direction:  decreasing

# %% [markdown]
# If you *just* want the **coordinate values**, you guessed it:

# %%
# 41
t2m_mean.latitude.values
# Out:
# array([21.25, 21.  , 20.75, 20.5 , 20.25, 20.  , 19.75, 19.5 , 19.25,
#        19.  , 18.75, 18.5 , 18.25, 18.  , 17.75, 17.5 , 17.25, 17.  ,
#        16.75, 16.5 , 16.25, 16.  , 15.75, 15.5 , 15.25, 15.  , 14.75,
#        14.5 , 14.25, 14.  , 13.75, 13.5 , 13.25, 13.  , 12.75, 12.5 ,
#        12.25, 12.  , 11.75, 11.5 , 11.25, 11.  , 10.75, 10.5 , 10.25,
#        10.  ,  9.75,  9.5 ,  9.25,  9.  ,  8.75,  8.5 ,  8.25,  8.  ,
#         7.75,  7.5 ,  7.25,  7.  ,  6.75,  6.5 ,  6.25,  6.  ,  5.75,
#         5.5 ,  5.25,  5.  ,  4.75,  4.5 ])

# %% [markdown]
# `xarray` and `matplotlib` go hand in hand. You can plot an xarray.DataArray as simple as:

# %%
# 42
t2m_mean.plot()

# %% [markdown]
# Now that doesn't look too aesthetic, so let's pimp it a bit:

# %%
# 43
# =============================================================
# ✏️ A 2D map of mean temperature over the Philippines
# =============================================================

lsm = xr.open_dataarray("../data/processed/land-sea-mask_0p00833333.nc")       # ✏️ "land_sea_mask.nc" -> open with either `open_dataarray` or `open_dataset`. If you choose `open_dataset`, you need to select the variable inside ["land_sea_mask"]

fig, ax = plt.subplots(figsize=(6, 8))

t2m_mean.plot(ax=ax,                # 💡 instead of `ax.plot`, with xarray we can now specify the ax in the native `plot` method
              cmap="RdYlBu_r",      # 💡 cmap means colormap, here "RdYlBu_r" stands for Red->Yellow->Blue, reversed
              vmin=20,              # 💡 set the minimum value of the colorbar to 20°C
              vmax=30)              # 💡 set the maximum value of the colorbar to 30°C

# 💡 the land-sea mask from ERA5 has values from zero (water) to one (land) and everything in between. We can use it to make contour lines:
ax.contour(lsm.lon, lsm.lat, lsm.values>0.5, colors="black",
           linewidths=0.3)

# mark Bacolod
ax.scatter(122.95, 10.68, color="black", s=30)
ax.text(123.2, 10.8, "Bacolod", fontsize=9, fontweight="bold", color="black")

ax.set_title("Mean 2m Temperature — Philippines\n1991–2020 (ERA5)")
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_aspect("equal")

# %% [markdown]
# > 💬 **Discussion:** Which regions are warmest? Which are coolest? Can you explain the pattern?
#
# ---
#
# ### 🖊️ Your turn: precipitation map
#
# Using the temperature map above as a template, make the same kind of map for **mean annual precipitation** (`tp_mean_annual`).
#
# **Tips:**
# - Use `cmap="YlGnBu"` (yellow = dry, blue = wet)
# - The precipitation range is roughly 500–5000 mm/year; set `vmin=500, vmax=5000`
# - Change the colorbar label to `"Mean annual precipitation (mm/yr)"`

# %%
# 44
fig, ax = plt.subplots(figsize=(6, 8))

# ✏️ plot tp_mean_annual, you can use the colormap "YlGnBu" (yellow-green-blue):
t2m_mean.plot(ax=ax,
              cmap="YlGnBu",
              vmin=500,
              vmax=5000)

# ✏️ use lsm to add contour lines for land and sea:
ax.contour(lsm.lon, lsm.lat, lsm.values>0.5, colors="black",
           linewidths=0.3)

# ✏️ mark Bacolod:
ax.scatter(122.95, 10.68, color="black", s=30)
ax.text(123.2, 10.8, "Bacolod", fontsize=9, fontweight="bold", color="black")

ax.set_title("Mean Annual Precipitation — Philippines\n1991–2020 (ERA5)")
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_aspect("equal")

# %% [markdown]
# > 💬 **Discussion:** Which regions are wettest? Driest?
#
# ---
#
# ## 2) What climate does Bacolod have?
#
# We'll extract temperature and precipitation data for **Bacolod** (10.68°N, 122.95°E) and look at:
# 1. The long-term temperature trend (1940–2024)
# 2. The typical annual cycle of temperature and rainfall (the *climatological* monthly means over 1991–2020)

# %%
print(type(t2m_yearly))
print(t2m_yearly)
# Out:
# <class 'str'>
# t2m_bacolod_yearly.nc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1013/2301173399.py in <cell line: 0>()
#       2 print(t2m_yearly)
#       3
# ----> 4 xr.open_dataset("../data/processed/day1/t2m_yearly.csv")
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     585
#     586     if engine is None:
# --> 587         engine = plugins.guess_engine(filename_or_obj)
#     588
#     589     if from_array_kwargs is None:
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/plugins.py in guess_engine(store_spec, must_support_groups)
#     210         )
#     211
# --> 212     raise ValueError(error_msg)
#     213
#     214
#
# ValueError: did not find a match in any of xarray's currently installed IO backends ['h5netcdf', 'scipy']. Consider explicitly selecting one of the installed engines via the ``engine`` parameter, or installing additional IO dependencies, see:
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html
# https://docs.xarray.dev/en/stable/user-guide/io.html

# %%
# 45
# --- Load Bacolod ERA5 time series ---
t2m_yearly  = "t2m_bacolod_yearly.nc" # "t2m_bacolod_yearly.nc"
t2m_monthly = "t2m_bacolod_monthly.nc" # "t2m_bacolod_monthly.nc"
tp_monthly  = "tp_bacolod_monthly.nc" # "tp_bacolod_monthly.nc"

# %%
# 46
# --- Long-term temperature trend in Bacolod ---
years = t2m_yearly["year"].values
temps = t2m_yearly["Temperature"].values

# Fit a linear trend
trend_coeffs = np.polyfit(years, temps, 1)
trend_line   = np.polyval(trend_coeffs, years)
warming_per_decade = trend_coeffs[0] * 10

fig, ax = plt.subplots(figsize=(11, 4))

ax.plot(years, temps, color="tomato", linewidth=1.2, alpha=0.8, label="Yearly mean T")  # 💡 exactly the same as t2m_yearly.plot(ax=ax, ...)
ax.plot(years, trend_line, color="darkred", linewidth=2.5, linestyle="--",
        label=f"Linear trend (+{warming_per_decade:.2f} °C / decade)")

ax.set_title("Annual Mean Temperature in Bacolod (ERA5, 1940–2024)")
ax.set_xlabel("Year")
ax.set_ylabel("Temperature (°C)")
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1013/3965330513.py in <cell line: 0>()
#       1 # 46
#       2 # --- Long-term temperature trend in Bacolod ---
# ----> 3 years = t2m_yearly["years"].values # ✏️ get the values of the "year" coordinate from t2m_yearly
#       4 temps = t2m_yearly.values # ✏️ get the temperature values in t2m_yearly
#       5
#
# TypeError: string indices must be integers, not 'str'

# %% [markdown]
# > 💬 **Discussion:** How does the warming rate in Bacolod compare to the global average (~0.18 °C/decade since 1981)?
#
# ---
#
# Now let's look at the **annual cycle** — the typical pattern of temperature and rainfall throughout the year. This is what characterises a place's *climate*.

# %%
# 47
# =============================================================
# 💡 EXAMPLE — Monthly mean temperature (1991–2020 climatology)
# =============================================================

month_names = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
               "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(range(1, 13), t2m_monthly.values,
        color="tomato", linewidth=2, marker="o", markersize=6)

ax.set_xticks(range(1, 13))
ax.set_xticklabels(month_names)
ax.set_ylim(24, 32)

ax.set_title("Monthly Mean Temperature — Bacolod\n1991–2020 climatology (ERA5)")
ax.set_xlabel("Month")
ax.set_ylabel("Temperature (°C)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1013/2206348265.py in <cell line: 0>()
#       9 fig, ax = plt.subplots(figsize=(8, 4))
#      10
# ---> 11 ax.plot(range(1, 13), t2m_monthly.values,
#      12         color="tomato", linewidth=2, marker="o", markersize=6)
#      13
#
# AttributeError: 'str' object has no attribute 'values'

# %% [markdown]
# For reference, here's the same for Belgium:
#
# <img src="https://github.com/Cas-Dec/USLS-Workshop/blob/main/notebooks/images/KMI_Belgium_temperatures.png?raw=1" alt="Belgium Monthly Temperature" style="width:60%">
#
# > 💬 **Discussion:** Is there a lot of temperature variability throughout the year in Bacolod? Compare with that of Belgium. Why do you think this is?
#
# ### 🖊️ Your turn: monthly precipitation
#
# Make the same kind of plot for **monthly mean precipitation** (`tp_monthly`) — the average rainfall for each month of the year.
#
# **Tips:**
# - Use bars instead of a line: `ax.bar(...)`
# - Set y-axis label to `"Precipitation (mm/month)"`
# - Use the same `month_names` list for x-tick labels

# %%
# 48
# ✏️ initialize fig and ax
...

# ✏️ Make a bar chart of monthly mean precipitation:
ax.bar(...)

# 💡 range(1, 13) is just 1, 2, ..., 12
ax.set_xticks(range(1, 13))

# ✏️ set the x-tick labels to the month names:
ax.set_xticklabels(...)

ax.set_title("Monthly Mean Precipitation — Bacolod\n1991–2020 climatology (ERA5)")
ax.set_xlabel("Month")

# ✏️ set the y-axis label to "Precipitation (mm/month)":
...

# %% [markdown]
# > 💬 **Discussion:** Which months are wet and which are dry? What drives this seasonal pattern?
#
# ---
#
# ## 3) What is the Köppen-Geiger climate type of Bacolod?
#
# The **[Köppen-Geiger (KG) classification](https://en.wikipedia.org/wiki/K%C3%B6ppen_climate_classification)** is the most widely used climate scheme in the world. It was developed by German-Russian climatologist [Wladimir Köppen](https://en.wikipedia.org/wiki/Wladimir_K%C3%B6ppen) in 1884 — as a botanist, he designed it around the idea that *climate shapes vegetation*. As a result, the KG classes correspond strongly to [biomes](https://en.wikipedia.org/wiki/Biome), making it especially useful in biology.
#
# The system works as a **decision tree**. The five main climate groups are:
#
# | Group | Name | Main criterion |
# |-------|------|----------------|
# | **A** | Tropical | Coldest month ≥ 18°C |
# | **B** | Arid | Precipitation too low for forest |
# | **C** | Temperate | Coldest month −3°C to 18°C |
# | **D** | Continental | Coldest month < −3°C |
# | **E** | Polar | Warmest month < 10°C |
#
# Within **Group A**, the subtypes depend on rainfall seasonality:
#
# | Subtype | Name | Criterion |
# |---------|------|----------|
# | **Af** | Tropical rainforest | Driest month ≥ 60 mm |
# | **Am** | Tropical monsoon | Driest month < 60 mm, but annual P ≥ 25×(100 − driest month in mm) |
# | **Aw** | Tropical savanna | Otherwise |
#
# Let's compute the values we need from the ERA5 climatology.

# %%
# 49
# Values needed for the classification
coldest_month_T  = float(t2m_monthly.min())         # minimum monthly temperature. 💡 float converts a specified number or string into a floating-point number
warmest_month_T  = ...                              # ✏️ maximum monthly temperature. hint: max()
annual_precip    = ...                              # ✏️ annual total. hint: sum()
driest_month_P   = ...                              # ✏️ precipitation of driest month. hint: min()

print(f"Coldest month mean temperature : {coldest_month_T:.1f} °C")
print(f"Annual precipitation           : {annual_precip:.0f} mm")
print(f"Driest month precipitation     : {driest_month_P:.0f} mm")

# %% [markdown]
# Now let's write the decision tree in Python. The key tool is the `if / elif / else` structure.
#
# Here's a simple example first:

# %%
# 50
# =============================================================
# 💡 EXAMPLE — if / elif / else in Python
# =============================================================
temperature = 32

if temperature > 35:
    description = "Dangerously hot"
elif temperature > 30:
    description = "Very warm"
elif temperature > 20:
    description = "Comfortable"
else:
    description = "Cool"

print(f"At {temperature}°C: {description}")

# You can also combine conditions with 'and' / 'or':
driest = 35
annual = 1800

if driest < 60 and annual >= 25 * (100 - driest):
    print("This would be Am (tropical monsoon)")

# %% [markdown]
# ### 🖊️ Your turn: classify Bacolod's climate
#
# Using the three values computed above (`coldest_month_T`, `annual_precip`, `driest_month_P`) and the table of criteria, complete the decision tree below.
#
# Work through the conditions in order:
# 1. First determine the main group (A, B, C, D, or E)
# 2. If it is Group A, determine the subtype (Af, Am, or Aw)

# %%
# 51
# ✏️ Complete this decision tree:

# Step 1: determine main group

    # first condition: if coldest_month_T >= 18, then it's Group A (tropical)
if coldest_month_T >= ...:
    group = "..."   # Tropical
    # second condition: if annual_precip < ???, then it's Group B (ARID)
elif annual_precip < ...:
    group = "..."   # Arid
    # third: for temperate
elif ... >= ...:
    ...             # Temperate
elif ... >= ... & ... < ...:
    ...             # Polar
else:
    ...             # Continental

# Step 2: if Group A, find the subtype
if group == "A":
    if driest_month_P >= 60:
        subtype = "f"   # Af — rainforest
    # elif driest_month_P < 60 and ???:
    #     subtype = "m"   # Am — monsoon
    # else:
    #     subtype = "w"   # Aw — savanna
else:
    subtype = ""   # (we won't classify further for non-A groups today)

climate_code = group + subtype
print(f"Bacolod's Köppen-Geiger climate type: {climate_code}")

# %% [markdown]
# > 💬 **Discussion:** According to Wikipedia, the Philippines has five climate types: tropical rainforest, tropical monsoon, tropical savanna, humid subtropical and oceanic. What would you expect for Bacolod? Does your result match?
#
# ---
#
# ## 4) Climate zones in the Philippines — present and future
#
# To finish, let's zoom out. The Köppen-Geiger system has been applied globally, and researchers have used climate models to project how these zones will shift under continued warming.
#
# [Beck et al. (2023)](https://doi.org/10.1038/s41597-023-02549-6) published 1 km resolution KG maps for 1901–2099 based on [CMIP6](https://en.wikipedia.org/wiki/Coupled_Model_Intercomparison_Project) climate model projections:
#
# > Beck, H. E., McVicar, T. R., Vergopolan, N., Berg, A., Lutsko, N. J., Dufour, A., ... & Miralles, D. G. (2023). High-resolution (1 km) Köppen-Geiger maps for 1901–2099 based on constrained CMIP6 projections. *Scientific Data, 10*(1), 724.
#
# Below is an example of how climate zones across the Philippines might shift by 2100 under a high-emissions scenario. Notice how tropical rainforest areas (Af) may contract, with savanna-type conditions (Aw) expanding as rainfall seasonality increases.
#
# *(Interactive maps and downloads available at: https://www.gloh2o.org/koppen/)*

# %%
# 52
from workshop_utils.plotting import plot_kg_map

# --- Present climate: 1991–2020 ---
ds_present = xr.open_dataset("../data/processed/kg_philippines_present.nc")
kg_present = ds_present[list(ds_present.data_vars)[0]].squeeze()
kg_present = kg_present.where(kg_present > 0)   # 0 = ocean/no-data in Beck et al.'s files, not a real class - mask it out so it isn't drawn

fig, ax = plt.subplots(figsize=(7, 9))
patches = plot_kg_map(ax, kg_present, title="Present climate (1991–2020)")
fig.legend(handles=patches, loc="lower center", ncol=min(len(patches), 6),
           frameon=False, title="Köppen-Geiger class", fontsize=9)
fig.suptitle("Köppen-Geiger Climate Classification — Philippines\n(Beck et al. 2023)", fontsize=13)
plt.tight_layout(rect=[0, 0.07, 1, 1])

# %%
# 53
# --- Future climate: 2071–2099, SSP4-6.0 ---
ds_future  = xr.open_dataset("../data/processed/kg_philippines_future_ssp460.nc")
kg_future  = ds_future[list(ds_future.data_vars)[0]].squeeze()
kg_future  = kg_future.where(kg_future > 0)   # same 0 = ocean/no-data sentinel as the present-day file

fig, ax = plt.subplots(1, 2, figsize=(15, 9))

patches_1 = plot_kg_map(ax[0], kg_present, title="Present climate (1991–2020)")
patches_2 = plot_kg_map(ax[1], kg_future, title="Future climate (2071–2099, SSP4-6.0)")

fig.legend(handles=patches_2, loc="lower center", ncol=min(len(patches_2), 6),
           frameon=False, title="Köppen-Geiger class", fontsize=9)
fig.suptitle("Köppen-Geiger Climate Classification — Philippines\n(Beck et al. 2023)", fontsize=13)
plt.tight_layout(rect=[0, 0.07, 1, 1])

# %% [markdown]
# > 💬 **Final discussion:**
# > - What does a shift in Köppen-Geiger zone mean for the ecosystems and agriculture of a region?
# > - If Bacolod's climate shifts from Af to Am, what would change about day-to-day life and biodiversity here?
# > - What can individuals, communities, and governments do in response?
#
# ---
#
# ## Well done!
#
# Today you:
# - Loaded and visualised real climate data from NASA, NOAA, and ECMWF
# - Saw how different potential climate drivers (sun, volcanoes, ENSO, CO₂) compare to the observed warming trend
# - Explored the climate of the Philippines and Bacolod using ERA5 reanalysis data
# - Classified Bacolod according to the Köppen-Geiger system
# - Got acquainted with Python, and concepts such as `variables`, `functions` and `classes`
# - Learned to work with a bunch of core Python libraries: `numpy`, `pandas`, `xarray`, and `matplotlib`
#
# **Tomorrow (Day 2)** we'll go further into biological data — species distributions, ecological surveys, and what data science can tell us about biodiversity.
